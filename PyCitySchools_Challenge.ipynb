# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read the School Data and Student Data and store into a Pandas DataFrame
school_data_df = pd.read_csv(school_data_to_load)
student_data_df = pd.read_csv(student_data_to_load)

# Cleaning Student Names and Replacing Substrings in a Python String
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# Iterate through the words in the "prefixes_suffixes" list and replace them with an empty space, "".
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")

# Check names.
student_data_df.head(10)
# Out:
# C:\Users\Range\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#    Student ID     student_name gender grade        school_name  reading_score  \
# 0           0     Paul Bradley      M   9th  Huang High School             66
# 1           1     Victor Smith      M  12th  Huang High School             94
# 2           2  Kevin Rodriguez      M  12th  Huang High School             90
# 3           3    Richard Scott      M  12th  Huang High School             67
# 4           4       Bonnie Ray      F   9th  Huang High School             97
# 5           5    Bryan Miranda      M   9th  Huang High School             94
# 6           6    Sheena Carter      F  11th  Huang High School             82
# 7           7     Nicole Baker      F  12th  Huang High School             96
# 8           8     Michael Roth      M  10th  Huang High School             95
# ...

# %%
# Install numpy using conda install numpy or pip install numpy. 
# Step 1. Import numpy as np.
import numpy as np

# %%
student_data_df.loc[student_data_df["reading_score"]>=70]
# Out:
#        Student ID     student_name gender grade         school_name  \
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 1                 94          61
# 2                 90          60
# 4                 97          84
# ...

# %%
student_data_df.loc[(student_data_df["reading_score"]>=70)&(student_data_df["math_score"]>=70)]
# Out:
#        Student ID     student_name gender grade         school_name  \
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# 9               9   Matthew Greene      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 4                 97          84
# 5                 94          94
# 6                 82          80
# ...

# %%
student_data_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# 2                 90          60
# ...

# %%
student_data_df.loc[(student_data_df["school_name"] == "Thomas High School") & (student_data_df["grade"]=="9th")]
# Out:
#        Student ID      student_name gender grade         school_name  \
# 37537       37537       Erik Snyder      M   9th  Thomas High School
# 37538       37538    Tanya Martinez      F   9th  Thomas High School
# 37539       37539     Noah Erickson      M   9th  Thomas High School
# 37540       37540      Austin Meyer      M   9th  Thomas High School
# 37543       37543   Madison Hampton      F   9th  Thomas High School
# ...           ...               ...    ...   ...                 ...
# 39152       39152        Lori Moore      F   9th  Thomas High School
# 39153       39153   William Hubbard      M   9th  Thomas High School
# 39157       39157  Kristen Gonzalez      F   9th  Thomas High School
# 39164       39164    Joseph Anthony      M   9th  Thomas High School
# 39167       39167    Rebecca Tanner      F   9th  Thomas High School
#
#        reading_score  math_score
# 37537             80          90
# 37538             71          69
# 37539             86          76
# ...

# %%
student_data_df.loc[(student_data_df["school_name"] == "Thomas High School") & (student_data_df["grade"]=="9th"),"reading_score"]=np.NaN

# %%
student_data_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0               66.0          79
# 1               94.0          61
# 2               90.0          60
# ...

# %%
student_data_df.loc[(student_data_df["school_name"] == "Thomas High School") & (student_data_df["grade"]=="9th"),"math_score"]=np.NaN

# %%
student_data_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0               66.0        79.0
# 1               94.0        61.0
# 2               90.0        60.0
# ...

# %%
student_count=school_data_df[school_data_df["school_name"]=="Thomas High School"]
student_count
# Out:
#     School ID         school_name     type  size   budget
# 14         14  Thomas High School  Charter  1635  1043130

# %%
student_count_test=student_data_df[student_data_df["grade"]!="9th"]
student_count_test
# Out:
#        Student ID     student_name gender grade         school_name  \
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 7               7     Nicole Baker      F  12th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39163       39163       John Reese      M  11th  Thomas High School
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 1               94.0        61.0
# 2               90.0        60.0
# 3               67.0        58.0
# ...

# %%
student_count_test.count()
# Out:
# Student ID       27762
# student_name     27762
# gender           27762
# grade            27762
# school_name      27762
# reading_score    27762
# math_score       27762
# dtype: int64

# %%
passing_both=student_count_test.loc[(student_count_test["reading_score"]>=70)&(student_count_test["math_score"]>=70)]

# %%
passing_reading=student_count_test.loc[(student_count_test["reading_score"]>=70)]

# %%
passing_math=student_count_test.loc[(student_count_test["math_score"]>=70)]

# %%
student_data_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0               66.0        79.0
# 1               94.0        61.0
# 2               90.0        60.0
# ...

# %%
student_data_df_merge=pd.merge(student_count,student_count_test)

# %%
student_data_df_merge
# Out:
#       School ID         school_name     type  size   budget  Student ID  \
# 0            14  Thomas High School  Charter  1635  1043130       37535
# 1            14  Thomas High School  Charter  1635  1043130       37536
# 2            14  Thomas High School  Charter  1635  1043130       37541
# 3            14  Thomas High School  Charter  1635  1043130       37542
# 4            14  Thomas High School  Charter  1635  1043130       37544
# ...         ...                 ...      ...   ...      ...         ...
# 1169         14  Thomas High School  Charter  1635  1043130       39163
# 1170         14  Thomas High School  Charter  1635  1043130       39165
# 1171         14  Thomas High School  Charter  1635  1043130       39166
# 1172         14  Thomas High School  Charter  1635  1043130       39168
# 1173         14  Thomas High School  Charter  1635  1043130       39169
#
#            student_name gender grade  reading_score  math_score
# ...

# %%
#get the total number of students
student_count=student_data_df_merge["Student ID"].count()
student_count
# Out:
# 1174

# %%
#number of students passing math
passing_math=student_data_df_merge.loc[(student_data_df_merge["math_score"]>=70)].count()


#number of students passing reading
passing_reading=student_data_df_merge.loc[(student_data_df_merge["reading_score"]>=70)].count()

#number of students passing both
passing_both=student_data_df_merge.loc[(student_data_df_merge["reading_score"]>=70)&(student_data_df_merge["math_score"]>=70)].count()

# %%
#passing both
passing_both_percentage=passing_both/float(student_count)*100

# %%
school_count=school_count=school_data_df["school_name"].count()

# %%
total_budget=school_data_df["budget"].sum()

# %%
student_count_all=student_data_df["Student ID"].count()
student_count_all
# Out:
# 39170

# %%
average_reading_all=student_data_df["reading_score"].mean()
average_math_all=student_data_df["math_score"].mean()
passing_math_all=student_data_df["math_score"]>=70
passing_reading_all=student_data_df["reading_score"]>=70
passing_both_all=student_data_df[(student_data_df["math_score"]>=70)&(student_data_df["reading_score"]>=70)]

# %%
#percent passing math
passing_math_percentage_all=passing_math_all/float(student_count_all)*100

#percent passing reading
passing_reading_percentage_all=passing_reading_all/float(student_count_all)*100

# %%
passing_both_all_count=passing_both_all.count()

# %%
overall_passing_percentage=passing_both_all_count/float(student_count_all)*100
